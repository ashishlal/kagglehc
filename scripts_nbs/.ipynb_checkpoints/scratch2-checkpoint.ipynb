# %%
import numpy as np
import pandas as pd

from fastai.vision import *
import torchvision.models as modelstv
from sklearn.metrics import roc_auc_score

import warnings
warnings.simplefilter('ignore', category=FutureWarning)
warnings.simplefilter('ignore', category=UserWarning)

# %matplotlib inline

torch.backends.cudnn.benchmark = True

# %%
train_df = pd.read_csv('../data/train_labels.csv.zip')
print(train_df.shape)
train_df.head()
# Out:
# (220025, 2)
#                                          id  label
# 0  f38a6374c348f90b587e046aac6079959adf3835      0
# 1  c18f2d887b7ae4f6742ee445113fa1aef383ed77      1
# 2  755db6279dae599ebb4d39a9123cce439965282d      0
# 3  bc3f0c64fb968ff4a8bd33af6971ecae77c75e08      0
# 4  068aba587a4950175d04c680d38943fd488d6a9d      0

# %%
train_df['label'].value_counts()
# Out:
# 0    130908
# 1     89117
# Name: label, dtype: int64

# %%
train_df['label'].value_counts(normalize=True)
# Out:
# 0    0.594969
# 1    0.405031
# Name: label, dtype: float64

# %%
src = (ImageItemList.from_csv('../data/', folder='train', csv_name='train_labels.csv.zip', suffix='.tif')
      .random_split_by_pct(0.1, seed=77)
      .label_from_df()
      .add_test_folder())

# %%
??get_transforms

# %%
# tfms = get_transforms(do_flip=True, flip_vert=True, max_rotate=45.0, max_zoom=1.2, max_lighting=0.5, max_warp=0)

tfms = get_transforms(do_flip=True, flip_vert=True, max_rotate=45.0, max_zoom=1.2, max_lighting=0.5, 
                      max_warp=0.,p_affine=0.7,p_lighting=0.75)

data = (src.transform(tfms, size=96, resize_method=ResizeMethod.SQUISH)
       .databunch(bs=64, path='.'))

data.normalize(imagenet_stats);

# %%
data.show_batch(rows=5, figsize=(15, 15))

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=1., gamma=1.):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets, **kwargs):
        CE_loss = nn.CrossEntropyLoss(reduction='none')(inputs, targets)
        pt = torch.exp(-CE_loss)
        F_loss = self.alpha * ((1-pt)**self.gamma) * CE_loss
        return F_loss.mean()

    
def roc_score(inp, target):
    _, indices = inp.max(1)
    return torch.Tensor([roc_auc_score(target, indices)])[0]

# %%
loss_func = FocalLoss(gamma=1.)
learn = create_cnn(data, models.densenet121, metrics=[accuracy, roc_score], loss_func=loss_func)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-ab4012807a2f> in <module>()
#       1 loss_func = FocalLoss(gamma=1.)
# ----> 2 learn = create_cnn(data, models.densenet121, metrics=[accuracy, roc_score], loss_func=loss_func)
#
# AttributeError: module 'fastai.vision.models' has no attribute 'densenet121'
